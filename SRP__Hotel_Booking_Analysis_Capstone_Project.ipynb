# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikant04101997/Hotel_Booking_Anaylsis/blob/main/SRP__Hotel_Booking_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ###### **Project Type**    -   Exploratary Data Analysis(EDA)
# ##### **Contribution**    -   Individual
# ##### **Team Member 1 **  - Shrikant Mahalle
# ##### **Team Member 2 **  - Rohit Thakare

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project contains the real world data record of hotel bookings of a city and a resort hotel containing details like bookings, cancellations, guest details etc. from 2015 to 2017. Main aim of the project is to understand and visualize dataset from hotel and customer point of view i.e.
#
# 1. reasons for booking cancellations across various parameters
# 2. best time to book hotel
# 3. peak season
#
# and give suggestions to reduce these cancellations and increase revenue of hotels.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **For this project we will be analyzing Hotel Booking data. This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces.
#   Hotel industry is a very volatile industry and the bookings depends on above factors and many more.
#   The main objective behind this project is to explore and analyze data to discover important factors that govern the bookings and give insights to hotel management ,which can perform various campaigns to boost the business and performance.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# **We are provided with a hotel bookings dataset.Out main objective is perform EDA on the given dataset and draw useful conclusions about general trends in hotel bookings and how factors governing hotel bookings interact with each other.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing Libraries
from io import IncrementalNewlineDecoder
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
import pandas as pd
url= 'https://drive.google.com/file/d/1C9AxF9fcVzMw0Bgs0NaRrNML2WwX1Ehm/view?usp=share_link'
url='https://drive.google.com/uc?id=' + url.split('/')[-2]
srp = pd.read_csv(url)

# %% [markdown]
# ### Dataset First View

# %%
# reading csv file
srp.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
srp.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
#Checking the shape of data(rows & Columns)
print(f'We have total {srp.shape[0]} rows & {srp.shape[1]} columns.')
# Out:
# We have total 119390 rows & 32 columns.

# %% [markdown]
# ### Dataset Information

# %%
#Looking for the data Type & non-null values 
srp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#Looking at the count , unique, top, freq, mean,std , etc.
srp.describe(include = 'all')
# Out:
#              hotel    is_canceled      lead_time  arrival_date_year  \
# count       119390  119390.000000  119390.000000      119390.000000
# unique           2            NaN            NaN                NaN
# top     City Hotel            NaN            NaN                NaN
# freq         79330            NaN            NaN                NaN
# mean           NaN       0.370416     104.011416        2016.156554
# std            NaN       0.482918     106.863097           0.707476
# min            NaN       0.000000       0.000000        2015.000000
# 25%            NaN       0.000000      18.000000        2016.000000
# 50%            NaN       0.000000      69.000000        2016.000000
# 75%            NaN       1.000000     160.000000        2017.000000
# max            NaN       1.000000     737.000000        2017.000000
#
#        arrival_date_month  arrival_date_week_number  \
# count              119390             119390.000000
# ...

# %%
#Columns in the Hotel Booking Data
srp.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Creating a copy of dataframe
SRP_Analysis = srp.copy()

# %% [markdown]
# **Data Description:**

# %% [markdown]
# 1. **hotel** : *Hotel(Resort Hotel or City Hotel)*
#
# 2. **is_canceled** : *Value indicating if the booking was canceled (1) or not (0)*
#
# 3. **lead_time** :* Number of days that elapsed between the entering date of the booking into the PMS and the arrival date*
#
# 4. **arrival_date_year** : *Year of arrival date*
#
# 5. **arrival_date_month** : *Month of arrival date*
#
# 6. **arrival_date_week_number** : *Week number of year for arrival date*
#
# 7. **arrival_date_day_of_month** : *Day of arrival date*
#
# 8. **stays_in_weekend_nights** : *Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel*
#
# 9. **stays_in_week_nights** : *Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel*
#
# 10. **adults** : *Number of adults*
#
# 11. **children** : *Number of children*
#
# 12. **babies** : *Number of babies*
#
# 13. **meal** : *Type of meal booked. Categories are presented in standard hospitality meal packages:*
#
# 14. **country** : *Country of origin.`*
#
# 15. **market_segment** : *Market segment designation. In categories, the term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 16. **distribution_channel** : *Booking distribution channel. The term “TA” means “Travel Agents” and “TO” means “Tour Operators”*
#
# 17. **is_repeated_guest** : *Value indicating if the booking name was from a repeated guest (1) or not (0)*
#
# 18. **previous_cancellations** : *Number of previous bookings that were cancelled by the customer prior to the current booking*
#
# 19. **previous_bookings_not_canceled** : *Number of previous bookings not cancelled by the customer prior to the current booking*
#
# 20. **reserved_room_type** : *Code of room type reserved. Code is presented instead of designation for anonymity reasons.*
#
# 21. **assigned_room_type** : *Code for the type of room assigned to the booking.*
#
# 22. **booking_changes** : *Number of changes/amendments made to the booking from the moment the booking was entered on the PMS until the moment of check-in or cancellation*
#
# 23. **deposit_type** : *Indication on if the customer made a deposit to guarantee the booking.*
#
# 24. **agent** : *ID of the travel agency that made the booking*
#
# 25. **company** : *ID of the company/entity that made the booking or responsible for paying the booking.*
#
# 26. **days_in_waiting_list** : *Number of days the booking was in the waiting list before it was confirmed to the customer*
#
# 27. **customer_type** : *Type of booking, assuming one of four categories*
#
#
# 28. **adr** : *Average Daily Rate as defined by dividing the sum of all lodging transactions by the total number of staying nights*
#
# 29. **required_car_parking_spaces** : *Number of car parking spaces required by the customer*
#
# 30. **total_of_special_requests** :* Number of special requests made by the customer (e.g. twin bed or high floor)*
#
# 31. **reservation_status** : *Reservation last status, assuming one of three categories*
# * Canceled – booking was canceled by the customer
# * Check-Out – customer has checked in but already departed
# * No-Show – customer did not check-in and did inform the hotel of the reason why
#
#
#
#
#
# 32. **reservation_status_date** : *Date at which the last status was set. This variable can be used in conjunction with the ReservationStatus to understand when was the booking canceled or when did the customer checked-out of the hotel*

# %%
# converting object type to datetime
SRP_Analysis['reservation_status_date'] = pd.to_datetime(SRP_Analysis['reservation_status_date'], format = '%Y-%m-%d')

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# **In cleaning date we perform following step:**
#
# Remove duplicate rows.
#
# Handling missing values.
#
# unique values in categorical columns..
#
# Adding important columns

# %% [markdown]
# #### Duplicate Values

# %%
#Find the duplicate values
#True means duplicate value and false means original value
SRP_Analysis.duplicated().value_counts()
# Out:
# False    87396
# True     31994
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=SRP_Analysis.duplicated())
# Out:
# <Axes: ylabel='count'>

# %%
#Dropping the duplicate value
SRP_Analysis.drop_duplicates(inplace=True)

# %%
#Shape of original value
SRP_Analysis.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Columns having missing values.
SRP_Analysis.isnull().sum().sort_values(ascending = False)[:].reset_index().rename(columns={'index':'Columns',0:'Null Values'})
# Out:
#                            Columns  Null Values
# 0                          company        82137
# 1                            agent        12193
# 2                          country          452
# 3                         children            4
# 4               reserved_room_type            0
# 5               assigned_room_type            0
# 6                  booking_changes            0
# 7                     deposit_type            0
# 8                            hotel            0
# 9           previous_cancellations            0
# 10            days_in_waiting_list            0
# 11                   customer_type            0
# 12                             adr            0
# 13     required_car_parking_spaces            0
# 14       total_of_special_requests            0
# 15              reservation_status            0
# 16  previous_bookings_not_canceled            0
# 17               is_repeated_guest            0
# 18                     is_canceled            0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(14,7))
sns.heatmap(SRP_Analysis.isnull())
# Out:
# <Axes: >

# %%
#Replace null values with 0
null_columns = ['company','agent','children']
for column in null_columns:
  SRP_Analysis[column].fillna(0,inplace=True)

#In Country Column,Replace NA Value with Others
SRP_Analysis['country'].fillna(0,inplace=True)

# %%
#Succesfully Replace / Fill the null values
SRP_Analysis.isnull().sum().sort_values(ascending = False)[:].reset_index().rename(columns={'index':'Columns',0:'Null Values'})
# Out:
#                            Columns  Null Values
# 0                            hotel            0
# 1                      is_canceled            0
# 2               reservation_status            0
# 3        total_of_special_requests            0
# 4      required_car_parking_spaces            0
# 5                              adr            0
# 6                    customer_type            0
# 7             days_in_waiting_list            0
# 8                          company            0
# 9                            agent            0
# 10                    deposit_type            0
# 11                 booking_changes            0
# 12              assigned_room_type            0
# 13              reserved_room_type            0
# 14  previous_bookings_not_canceled            0
# 15          previous_cancellations            0
# 16               is_repeated_guest            0
# 17            distribution_channel            0
# 18                  market_segment            0
# ...

# %%
#checking for criteria for no booking.

SRP_Analysis[SRP_Analysis['adults']+SRP_Analysis['babies']+SRP_Analysis['children'] == 0].shape
# Out:
# (166, 32)

# %%
# Dropping those 116 rows in which no booking were made .

SRP_Analysis.drop(SRP_Analysis[SRP_Analysis['adults']+SRP_Analysis['babies']+SRP_Analysis['children'] == 0].index, inplace = True)

# %% [markdown]
# **3.unique values in categorical columns.**

# %%
# Checking the unique values in categorical columns.
categorical_cols=list(set(SRP_Analysis.drop(columns=['reservation_status_date','country','arrival_date_month']).columns)-set(SRP_Analysis.describe()))
for col in categorical_cols:
  print(f'Unique values in column {col} are:, {(SRP_Analysis[col].unique())}')
# Out:
# Unique values in column customer_type are:, ['Transient' 'Contract' 'Transient-Party' 'Group']
# Unique values in column assigned_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'I' 'B' 'H' 'L' 'K']
# Unique values in column deposit_type are:, ['No Deposit' 'Refundable' 'Non Refund']
# Unique values in column distribution_channel are:, ['Direct' 'Corporate' 'TA/TO' 'Undefined' 'GDS']
# Unique values in column meal are:, ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in column market_segment are:, ['Direct' 'Corporate' 'Online TA' 'Offline TA/TO' 'Complementary' 'Groups'
#  'Undefined' 'Aviation']
# Unique values in column hotel are:, ['Resort Hotel' 'City Hotel']
# Unique values in column reservation_status are:, ['Check-Out' 'Canceled' 'No-Show']
# Unique values in column reserved_room_type are:, ['C' 'A' 'D' 'E' 'G' 'F' 'H' 'L' 'B']

# %% [markdown]
# **4.Adding important columns**

# %%
# lets add some new columns

SRP_Analysis['total_people'] = SRP_Analysis['adults'] + SRP_Analysis['babies'] + SRP_Analysis['children'] 

SRP_Analysis['total_stay'] = SRP_Analysis['stays_in_weekend_nights'] + SRP_Analysis['stays_in_week_nights']

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# **EDA (Exploratory Data Analysis)**

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# **1) Which type of hotel is mostly preferred by the guests?**

# %%
# Chart - 1 visualization code
hotel_value_counts = SRP_Analysis['hotel'].value_counts()
hotel_value_counts
# Out:
# City Hotel      53274
# Resort Hotel    33956
# Name: hotel, dtype: int64

# %%
# Visualizsing the by pie chart.
SRP_Analysis['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=20)   
plt.title('Pie Chart for Most Preffered  Hotel')
# Out:
# Text(0.5, 1.0, 'Pie Chart for Most Preffered  Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We use pie chart because pie chart gives simple and easy to understand picture that shows which hotel has more bookings.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **We found that city hotel has more bookings which are 61.07% and Resort hotel has less bookings which are 38.9%.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, gained insights help creating a positive business impact.**
#
# **City hotel can find more services to attract more guests to increase more revenue.**
#
# **Resort hotel can find solution to attract guest and also find which facilities provided ny city hotel to attract the guest.**

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# **2) Which type of food is mostly preferred by the guests?**

# %%
# Chart - 5 visualization code
preferred_food = SRP_Analysis['meal'].value_counts()
preferred_food
# Out:
# BB           67907
# SC            9391
# HB            9080
# Undefined      492
# FB             360
# Name: meal, dtype: int64

# %%
#set plotsize
plt.figure(figsize=(18,8))

#plotting 
sns.countplot(x=SRP_Analysis['meal'])
# set xlabel for the plot
plt.xlabel('Meal Type')
# set y label for the plot
plt.ylabel('Count')
#set title for the plot
plt.title("Preferred Meal Type")
# Out:
# Text(0.5, 1.0, 'Preferred Meal Type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We have choose countplot to visualize most preferred food because countplot display the count of each observation for each category and here we have to represent food type vs food type count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found here is BB type food is most preferred.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Using this insight hotels can improve quality of other type of meals.**

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# **3) Which room type is in most demand?**

# %%
# Chart - 4 visualization code
room_type = SRP_Analysis['assigned_room_type'].value_counts()
room_type
# Out:
# A    46283
# D    22419
# E     7190
# F     3627
# G     2495
# C     2160
# B     1811
# H      706
# I      353
# K      185
# L        1
# Name: assigned_room_type, dtype: int64

# %%
#set plotsize
plt.figure(figsize=(18,8))

#plotting 
sns.countplot(x=SRP_Analysis['assigned_room_type'],order=SRP_Analysis['assigned_room_type'].value_counts().index)
#  set xlabel for the plot
plt.xlabel('Room Type')
# set y label for the plot
plt.ylabel('Count of Room Type')
#set title for the plot
plt.title("Most preferred Room type")
# Out:
# Text(0.5, 1.0, 'Most preferred Room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We have choose countplot to visualize most prefferd roomtype because countplot display the count of each observation for each category and here we have to represent room type vs room type count.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insighte found from the chart is A type rooms are most prefered rooms and the count is 46283 and after that D type rooms are prefered by the guest and count is 22419.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Hotels can provide those facilities in other room types which provided in room type A**

# %% [markdown]
# #### Chart - 4

# %% [markdown]
# **4) What is preferred stay length in each hotel?**

# %%
# Chart - 12 visualization code
stay_length = SRP_Analysis.groupby(['total_stay','hotel']).agg('count').reset_index()
stay_length = stay_length.iloc[:, :3]
stay_length = stay_length.rename(columns={'is_canceled':'Number of stays'})
stay_length
# Out:
#     total_stay         hotel  Number of stays
# 0            0    City Hotel              231
# 1            0  Resort Hotel              360
# 2            1    City Hotel            10270
# 3            1  Resort Hotel             6899
# 4            2    City Hotel            10813
# ..         ...           ...              ...
# 68          46  Resort Hotel                1
# 69          48    City Hotel                1
# 70          56  Resort Hotel                2
# 71          60  Resort Hotel                1
# 72          69  Resort Hotel                1
#
# [73 rows x 3 columns]

# %%
not_canceled = SRP_Analysis[SRP_Analysis['is_canceled'] == 0]
s1 = not_canceled[not_canceled['total_stay'] < 15]
plt.figure(figsize = (10,5))
sns.countplot(x = s1['total_stay'], hue = s1['hotel'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Because it gives simple visualization.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Optimal stay in both hotel type is less than 7 days.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **No there is no any business impact using this insight because that depend on tourist how many days they wna t to stay.**

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# **5) Which year had a highest booking ?**

# %%
# Chart - 5 visualization code
year_count = SRP_Analysis['arrival_date_year'].value_counts().sort_index()
year_count
# Out:
# 2015    13284
# 2016    42313
# 2017    31633
# Name: arrival_date_year, dtype: int64

# %%
# set plot size
plt.figure(figsize=(12,8))

#  plot with countplot
sns.countplot(x=SRP_Analysis['arrival_date_year'],hue=SRP_Analysis['hotel'])
plt.title("Year Wise bookings")
# Out:
# Text(0.5, 1.0, 'Year Wise bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Because countplot is easy to understand**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **2016 had highest bookings and 2015 had lowest bookings**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **No impact on a bussiness but review once why hotel booking is high in 2016. Is there any special occasion on this year or something else**

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# **6) In Which month most of the bookings happened ?**

# %%
# Chart - 6 visualization code
bookings_by_months=SRP_Analysis.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts of booking"})
sequence_of_months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
bookings_by_months['arrival_date_month']=pd.Categorical(bookings_by_months['arrival_date_month'],categories=sequence_of_months,ordered=True)
bookings_by_months=bookings_by_months.sort_values('arrival_date_month')
bookings_by_months
# Out:
#    arrival_date_month  Counts of booking
# 4             January               4685
# 3            February               6083
# 7               March               7489
# 0               April               7900
# 8                 May               8344
# 6                June               7756
# 5                July              10043
# 1              August              11242
# 11          September               6682
# 10            October               6921
# 9            November               4973
# 2            December               5112

# %%
# groupby arrival_date_month and taking the hotel count
bookings_by_months_df=SRP_Analysis.groupby(['arrival_date_month'])['hotel'].count().reset_index().rename(columns={'hotel':"Counts"})
# Create list of months in order
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
# creating df which will map the order of above months list without changing its values.
bookings_by_months_df['arrival_date_month']=pd.Categorical(bookings_by_months_df['arrival_date_month'],categories=months,ordered=True)
# sorting by arrival_date_month
bookings_by_months_df=bookings_by_months_df.sort_values('arrival_date_month')


# set plot size
plt.figure(figsize=(20,8))

#pltting lineplot on x- months & y- booking counts
sns.lineplot(x=bookings_by_months_df['arrival_date_month'],y=bookings_by_months_df['Counts'])

# set title for the plot
plt.title('Number of bookings across each month')
#set x label
plt.xlabel('Month')
#set y label
plt.ylabel('Number of bookings')
# Out:
# Text(0, 0.5, 'Number of bookings')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We choose lineplot here because it gives data visualization in simple form. So comparison becomes easy.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the chart is August month has maximum number of bookings.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **No impact on bussiness**

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# **7) Which hotel has high chance that its customer will return for another stay?**

# %%
# Selecting and counting repeated customers bookings
repeated_data = SRP_Analysis[SRP_Analysis['is_repeated_guest'] == 1]
repeat_grp = repeated_data.groupby('hotel')
D1 = pd.DataFrame(repeat_grp.size()).rename(columns = {0:'total_repeated_guests'})

# Counting total bookings
grouped_by_hotel = SRP_Analysis.groupby('hotel')
total_booking = grouped_by_hotel.size()
D2 = pd.DataFrame(total_booking).rename(columns = {0: 'total_bookings'})
D3 = pd.concat([D1,D2], axis = 1)

# Calculating repeat %
D3['repeat_%'] = round((D3['total_repeated_guests']/D3['total_bookings'])*100,2)

plt.figure(figsize = (10,5))
sns.barplot(x = D3.index, y = D3['repeat_%'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose barplot because it gives simple visualization of data.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Resort Hotel have high chance to customer will return for another stay**

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# **8) Which hotel has higher lead time?**

# %%
d2 = grouped_by_hotel['lead_time'].median().reset_index().rename(columns = {'lead_time':'median_lead_time'})
plt.figure(figsize = (8,5))
sns.barplot(x = d2['hotel'], y = d2['median_lead_time'] )
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose barplot because it gives simple visualization of data.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **City Hotel have highest lead time as compared to resort hotel"

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# **9) Which channel is mostly used for early booking of hotels?**

# %%
# Chart - 9 visualization code
# distribution channel value count
distribution_channel_counts = SRP_Analysis['distribution_channel'].value_counts()
distribution_channel_counts
# Out:
# TA/TO        69028
# Direct       12954
# Corporate     5062
# GDS            181
# Undefined        5
# Name: distribution_channel, dtype: int64

# %%
#shape of dataframe 
d3 = SRP_Analysis.shape[0]
d3
# Out:
# 87230

# %%
# booking by distribution channel in percent 
distribution_channel_df_percent = pd.DataFrame(round((distribution_channel_counts/d3)*100,2)).reset_index().rename(columns={'index':'distribution_channel','distribution_channel':'% booking'})
distribution_channel_df_percent
# Out:
#   distribution_channel  % booking
# 0                TA/TO      79.13
# 1               Direct      14.85
# 2            Corporate       5.80
# 3                  GDS       0.21
# 4            Undefined       0.01

# %%
group_by_dc = SRP_Analysis.groupby('distribution_channel')
d2 = pd.DataFrame(round(group_by_dc['lead_time'].median(),2)).reset_index().rename(columns = {'lead_time': 'median_lead_time'})
plt.figure(figsize = (7,5))
sns.barplot(x = d2['distribution_channel'], y = d2['median_lead_time'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **Because barplot gives simple and easy to understand pictorial chart.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Mostly used distribution channel is TA/TO channel.The total count of booking is 69028 and booking in percent is 79.13.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason

# %% [markdown]
# **This insight help to other channels to improve their services.**

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# **10) How much average price for room per night ?**

# %%
data2=SRP_Analysis[SRP_Analysis['is_canceled']==0]

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x="reserved_room_type",
            y="adr",
            hue="hotel",
            data=data2)
plt.title("Price of room types per night and person", fontsize=16)
plt.xlabel("Room type", fontsize=16)
plt.ylabel("Price [EUR]", fontsize=16)
plt.legend(loc="upper right")
plt.ylim(0, 600)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We use a boxplot for better understanding of price rate of room per night**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **This figure shows the average price per room, depending on its type and the standard deviation. Note that due to data anonymization rooms with the same type letter may not necessarily be the same across hotels.**

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# **11) Which agent made the most bookings?**

# %%
# Chart - 11 visualization code
top_bookings_by_agent = SRP_Analysis['agent'].value_counts().reset_index().rename(columns={'index':'agent','agent':'num_of_bookings'})[:10]
top_bookings_by_agent
# Out:
#    agent  num_of_bookings
# 0    9.0            28721
# 1  240.0            13028
# 2    0.0            12141
# 3   14.0             3342
# 4    7.0             3294
# 5  250.0             2779
# 6  241.0             1644
# 7   28.0             1493
# 8    8.0             1383
# 9    1.0             1228

# %%
# barplot is used for visualization
plt.figure(figsize=(14,7))
sns.barplot(x=top_bookings_by_agent['agent'],y=top_bookings_by_agent['num_of_bookings'],order=top_bookings_by_agent['agent'])
plt.title('Most bookings by the agent', fontsize=20)
plt.ylabel('Number of bookings', fontsize=15)
plt.xlabel('Agent number', fontsize=15)
# Out:
# Text(0.5, 0, 'Agent number')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We choose barplot here because it gives data visualization in pictorial form and due to this comparison of data is easy.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found here is Agent no. 9 made most of the bookings.**

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# **12) Which distribution channel brings better revenue generating deals for hotels?**

# %%
# Chart - 12 visualization 
distribution_channel = SRP_Analysis.groupby(['distribution_channel','hotel'])['adr'].mean().reset_index()
distribution_channel
# Out:
#   distribution_channel         hotel         adr
# 0            Corporate    City Hotel   83.777368
# 1            Corporate  Resort Hotel   53.036835
# 2               Direct    City Hotel  112.606688
# 3               Direct  Resort Hotel  106.566215
# 4                  GDS    City Hotel  120.317845
# 5                TA/TO    City Hotel  112.663552
# 6                TA/TO  Resort Hotel  101.578317
# 7            Undefined    City Hotel   29.625000
# 8            Undefined  Resort Hotel  112.700000

# %%
group_by_dc_hotel = SRP_Analysis.groupby(['distribution_channel', 'hotel'])
d5 = pd.DataFrame(round((group_by_dc_hotel['adr']).agg(np.mean),2)).reset_index().rename(columns = {'adr': 'avg_adr'})
plt.figure(figsize = (7,5))
sns.barplot(x = d5['distribution_channel'], y = d5['avg_adr'], hue = d5['hotel'])
plt.ylim(40,140)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose here barplot to visualise ADR across distribution channel beacuse it give easy to undertand visualization to large data.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the above chart is that GDS channel contributed most in ADR in city hotel and Direct and TA/TO has nearly equal contrivution in adr in both hotel types.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **This insight helps to GDS channel thet the have to increase booking in resort hotel type.**

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# **13) From which country the most guests are coming ?**

# %%
# Counting the guests from various countries.
country_df=SRP_Analysis['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})[:10]
# country_df1=df1['country'].value_counts().reset_index().rename(columns={'index': 'country','country': 'count of guests'})

# Visualizing by  plotting the graph
plt.figure(figsize=(20,8))
sns.barplot(x=country_df['country'],y=country_df['count of guests'])
plt.xlabel('Country')
plt.ylabel('Number of guests',fontsize=12)
plt.title("Number of guests from diffrent Countries")
# Out:
# Text(0.5, 1.0, 'Number of guests from diffrent Countries')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose barplot for better understanding guest which came from different countries**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Most guest are from Portugal and other European countries.**

# %% [markdown]
# #### Chart - 14

# %% [markdown]
# **14) Which Hotel type has the highest ADR?**

# %%
# group by hotel
grup_by_hotel=SRP_Analysis.groupby('hotel')

# %%
# Chart - 9 visualization code
highest_adr = SRP_Analysis.groupby('hotel')['adr'].mean().reset_index()
highest_adr
# Out:
#           hotel         adr
# 0    City Hotel  111.271969
# 1  Resort Hotel   99.059517

# %%
#grouping by hotel adr
highest_adr=grup_by_hotel['adr'].mean().reset_index()

#set plot size
plt.figure(figsize=(10,8))

# set labels
plt.xlabel('Hotel type')
plt.ylabel('ADR')
plt.title("Avg ADR of each Hotel type")

#plot the graph
sns.barplot(x=highest_adr['hotel'],y=highest_adr['adr'])
# Out:
# <Axes: title={'center': 'Avg ADR of each Hotel type'}, xlabel='hotel', ylabel='adr'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose bar plot because it gives simple pictirial diagram and it also easy to understand.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **The insight found from the chart is City hotel has highest adr that means city hotel generate more revenue.**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Yes, this insight is helpful for resort hotel that they can use this insight to increase there revenue.**

# %% [markdown]
# #### Chart - 15

# %% [markdown]
# **15) Waiting period effect on booking cancelation**

# %%
waiting_bookings = SRP_Analysis[SRP_Analysis['days_in_waiting_list'] !=0]  


fig, axes = plt.subplots(1, 2, figsize=(18, 8))
sns.kdeplot(ax=axes[0],x = 'days_in_waiting_list', hue = 'is_canceled' , data = waiting_bookings)
sns.kdeplot(ax = axes[1], x = SRP_Analysis['lead_time'], hue = SRP_Analysis['is_canceled'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose a kdeplot to understand the booking cancellation affected or not affected due to waiting time**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **We see that most of the bookings that are cancelled have waiting period of less 150 days but also most of bookings that are not cancelled also have waiting period less than 150 days. Hence this shows that waiting period has no effect on cancellation of bookings. \ \ Also, lead time has no affect on cancellation of bookings, as both curves of cancelation and not cncelation are similar for lead time too**

# %% [markdown]
# #### Chart - 16

# %% [markdown]
# **16) Effect of changing the allocated room on Booking cancelation ?**

# %%
def check_room_allot(x):
  if x['reserved_room_type'] != x['assigned_room_type']:
    return 1
  else:
    return 0

SRP_Analysis['same_room_not_alloted'] = SRP_Analysis.apply(lambda x : check_room_allot(x), axis = 1)
grp_by_canc = SRP_Analysis.groupby('is_canceled')

D3 = pd.DataFrame((grp_by_canc['same_room_not_alloted'].sum()/grp_by_canc.size())*100).rename(columns = {0: 'same_room_not_alloted_%'})
plt.figure(figsize = (10,7))
sns.barplot(x = D3.index, y = D3['same_room_not_alloted_%'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **I choose bar plot because it gives simple pictirial diagram and it also easy to understand.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **We see that not getting same room as demanded is not the case of cancellation of rooms. A significant percentage of bookings are not cancelled even after getting different room as demanded.**

# %% [markdown]
# #### Chart - 17

# %% [markdown]
# **17) Checking the booking percentage on differnt typeof customer i.e single, couple and family/friends**

# %%
single   = not_canceled[(not_canceled['adults']==1) & (not_canceled['children']==0) & (not_canceled['babies']==0)]
couple   = not_canceled[(not_canceled['adults']==2) & (not_canceled['children']==0) & (not_canceled['babies']==0)]
family   = not_canceled[not_canceled['adults'] + not_canceled['children'] + not_canceled['babies'] > 2]

reindex = ['January', 'February','March','April','May','June','July','August','September','October','November','December']

fig, ax = plt.subplots(figsize=(12, 8))

for type in ['single', 'couple', 'family']:
  d1 = eval(type).groupby(['arrival_date_month']).size().reset_index().rename(columns = {0:'arrival_num'})
  d1['arrival_date_month'] = pd.Categorical(d1['arrival_date_month'],categories=reindex,ordered=True)
  sns.lineplot(data=d1, x= 'arrival_date_month', y='arrival_num', label=type, ax=ax)
  
plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We use a line chart to compare a different type of customer**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Moslty bookings are done by couples(although we are not sure that they are couple as data doesn't tell about that)
# It is clear from graph that their is a sudden surge in arrival num of couples and family in months of July and August. So better plans can be planned accordingly at that time for these type of customers.**

# %% [markdown]
# #### Chart - 18

# %% [markdown]
# **18) Predicting whether or not a hotel was likely to receive a disproportionately high number of special requests?**

# %%
#Special request acoording to market segment
sns.boxplot(x="market_segment", y="total_of_special_requests",hue='market_segment',data= SRP_Analysis)

fig = plt.gcf()
fig.set_size_inches(15,10)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We use boxplot to undertand any special request raised or not**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **All of market segment mostly have special request.**

# %% [markdown]
# #### Chart - 19

# %% [markdown]
# **19)What is the percentage distribution of required_car_parking_spaces?**

# %%
SRP_Analysis['required_car_parking_spaces'].value_counts().plot.pie(explode=[0.05]*5, autopct='%1.1f%%',shadow=False,figsize=(12,8),fontsize=15,labels=None)

labels=SRP_Analysis['required_car_parking_spaces'].value_counts().index
plt.title('% Distribution of required car parking spaces')
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# **We use pie chart because pie chart gives simple and easy to understand picture that shows like guests required parking area or not.**

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Less quest required a parking space**

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# 1. City hotels are the most preferred hotel type by the guests. We can say City hotel is the busiest hotel.
# 2. BB (Bed & Breakfast) is the most preferred type of meal by the guests.
# 3. Most demanded room type is A.
# 4. Most common stay length is less than 4 days and generally people prefer City hotel for short    stay, but for long stays, Resort Hotel is preferred.
# 5. Most of the bookings for City hotels and Resort hotel were happened in 2016.
# 6. Most number of guests comes in month of August.
# 7. Both hotels have very small percentage that customer will repeat, but Resort hotel has slightly higher repeat % than City Hotel.
# 8. City hotel has slightly higher median lead time. Also median lead time is significantly higher in each case, this means customers generally plan their hotel visits way to early.
# 9. Most of the bookings were made through TA/TO (travel agents/Tour operators)
# 10. This figure shows the average price per room, depending on its type and the standard             deviation. Note that due to data anonymization rooms with the same type letter may not necessarily be the same across hotels.
# 11. The insight found here is Agent no. 9 made most of the bookings.
# 12. GDS channel brings higher revenue generating deals for City hotel, in contrast to that most    bookings come via TA/TO. City Hotel can work to increase outreach on GDS channels to get    more higher revenue generating deals.
# 13. Most guest are from Portugal and other European countries.
# 14. Average ADR for city hotel is high as compared to resort hotels. These City hotels are generating more revenue than the resort hotels.
# 15. We see that most of the bookings that are cancelled have waiting period of less 150 days but  also most of bookings that are not cancelled also have waiting period less than 150 days. Hence    this shows that waiting period has no effect on cancellation of bookings. \ \ Also, lead time has  no affect on cancellation of bookings, as both curves of cancelation and not cancelation are           similar    for lead time too
# 16. We see that not getting same room as demanded is not the case of cancellation of rooms.      A   significant percentage of bookings are not cancelled even after getting different room as        demanded
# 17. Moslty bookings are done by couples(although we are not sure that they are couple as data    doesn't tell about that)
# 18. It is clear from graph that their is a sudden surge in arrival num of couples and family in months of July and August. So better plans can be planned accordingly at that time for these type of   customers.
# 19. All of market segment mostly have special request.91.6 % guests did not required the parking space. only 8.3 % guests required only 1 parking space.
